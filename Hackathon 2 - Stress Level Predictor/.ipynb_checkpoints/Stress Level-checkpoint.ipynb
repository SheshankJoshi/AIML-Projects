# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import scipy
import seaborn as sns
import tensorflow.keras as k
import tensorflow
import time
import warnings 
warnings.filterwarnings('ignore')

# %%
train_folder="D:\\Work_folders\\datasets\\Hack Round the Clock - Datasets\\Train Data"
test_folder="D:\\Work_folders\\datasets\\Hack Round the Clock - Datasets\\Test Data"

# %%
df1=pd.read_csv(train_folder+"\\"+"frequency_domain_features_train.csv")
df2=pd.read_csv(train_folder+"\\"+"heart_rate_non_linear_features_train.csv")
df3=pd.read_csv(train_folder+"\\"+"time_domain_features_train.csv")

df1_test=pd.read_csv(test_folder+"\\"+"frequency_domain_features_test.csv")
df2_test=pd.read_csv(test_folder+"\\"+"heart_rate_non_linear_features_test.csv")
df3_test=pd.read_csv(test_folder+"\\"+"time_domain_features_test.csv")

# %%
df1.index=df1.uuid
df2.index=df2.uuid
df3.index=df3.uuid
df1_test.index=df1_test.uuid
df2_test.index=df2_test.uuid
df3_test.index=df3_test.uuid

# %%
(df1.index==df2.index).all(),(df2.index==df3.index).all()
# Out:
# (True, True)

# %%
df=pd.concat([df1,df2,df3],axis=1)
df_test=pd.concat([df1_test,df2_test,df3_test],axis=1)

# %%
df.head()
# Out:
#                                                                       uuid  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  89df2855-56eb-4706-a23b-b39363dd605a
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  80c795e4-aa56-4cc0-939c-19634b89cbb2
# c2d5d102-967c-487d-88f2-8b005a449f3e  c2d5d102-967c-487d-88f2-8b005a449f3e
# 37eabc44-1349-4040-8896-0d113ad4811f  37eabc44-1349-4040-8896-0d113ad4811f
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  aa777a6a-7aa3-4f6e-aced-70f8691dd2b7
#
#                                               VLF    VLF_PCT           LF  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  2661.894136  72.203287  1009.249419
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  2314.265450  76.975728   690.113275
# c2d5d102-967c-487d-88f2-8b005a449f3e  1373.887112  51.152225  1298.222619
# 37eabc44-1349-4040-8896-0d113ad4811f  2410.357408  70.180308  1005.981659
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  1151.177330  43.918366  1421.782051
#
#                                          LF_PCT      LF_NU         HF  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  27.375666  98.485263  15.522603
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  22.954139  99.695397   2.108525
# c2d5d102-967c-487d-88f2-8b005a449f3e  48.335104  98.950472  13.769729
# 37eabc44-1349-4040-8896-0d113ad4811f  29.290305  98.224706  18.181913
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  54.242160  96.720007  48.215822
#
#                                         HF_PCT     HF_NU           TP  ...  \
# uuid                                                                   ...
# 89df2855-56eb-4706-a23b-b39363dd605a  0.421047  1.514737  3686.666157  ...
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  0.070133  0.304603  3006.487251  ...
# c2d5d102-967c-487d-88f2-8b005a449f3e  0.512671  1.049528  2685.879461  ...
# 37eabc44-1349-4040-8896-0d113ad4811f  0.529387  1.775294  3434.520980  ...
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  1.839473  3.279993  2621.175204  ...
#
#                                           SKEW  MEAN_REL_RR MEDIAN_REL_RR  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  0.335218    -0.000203     -0.000179
# 80c795e4-aa56-4cc0-939c-19634b89cbb2 -0.155286    -0.000059      0.000611
# c2d5d102-967c-487d-88f2-8b005a449f3e -0.656813    -0.000011     -0.000263
# 37eabc44-1349-4040-8896-0d113ad4811f -0.386138     0.000112      0.000494
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7 -0.154252    -0.000100     -0.002736
#
#                                       SDRR_REL_RR  RMSSD_REL_RR  SDSD_REL_RR  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a     0.017080      0.007969     0.007969
# 80c795e4-aa56-4cc0-939c-19634b89cbb2     0.013978      0.004769     0.004769
# c2d5d102-967c-487d-88f2-8b005a449f3e     0.018539      0.008716     0.008716
# 37eabc44-1349-4040-8896-0d113ad4811f     0.017761      0.008660     0.008660
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7     0.023715      0.013055     0.013055
#
#                                       SDRR_RMSSD_REL_RR  KURT_REL_RR  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a           2.143342    -0.856554
# 80c795e4-aa56-4cc0-939c-19634b89cbb2           2.930855    -0.408190
# c2d5d102-967c-487d-88f2-8b005a449f3e           2.127053     0.351789
# 37eabc44-1349-4040-8896-0d113ad4811f           2.050988    -0.504947
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7           1.816544    -0.548408
#
#                                      SKEW_REL_RR  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a    0.335218
# 80c795e4-aa56-4cc0-939c-19634b89cbb2   -0.155286
# c2d5d102-967c-487d-88f2-8b005a449f3e   -0.656813
# 37eabc44-1349-4040-8896-0d113ad4811f   -0.386138
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7   -0.154252
#
#                                                                       uuid
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  89df2855-56eb-4706-a23b-b39363dd605a
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  80c795e4-aa56-4cc0-939c-19634b89cbb2
# c2d5d102-967c-487d-88f2-8b005a449f3e  c2d5d102-967c-487d-88f2-8b005a449f3e
# 37eabc44-1349-4040-8896-0d113ad4811f  37eabc44-1349-4040-8896-0d113ad4811f
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  aa777a6a-7aa3-4f6e-aced-70f8691dd2b7
#
# [5 rows x 39 columns]

# %%
for each in df:
    f1=plt.figure()
    sns.displot(df[each])
    f1.show()
    f2=plt.figure()
    sns.regplot(df[each],df["HR"])
    f2.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-8793665491e0> in <module>
#       2     f, (ax1, ax2) = plt.subplots(1, 2)
#       3     ax1=sns.displot(df[each])
# ----> 4     ax2=sns.regplot(df[each],df["HR"])
#       5     plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     836     scatter_kws["marker"] = marker
#     837     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 838     plotter.plot(ax, scatter_kws, line_kws)
#     839     return ax
#     840
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     368
#     369         if self.fit_reg:
# --> 370             self.lineplot(ax, line_kws)
#     371
#     372         # Label the axes
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in lineplot(self, ax, kws)
#     411         """Draw the model."""
#     412         # Fit the regression model
# --> 413         grid, yhat, err_bands = self.fit_regression(ax)
#     414         edges = grid[0], grid[-1]
#     415
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in fit_regression(self, ax, x_range, grid)
#     219             yhat, yhat_boots = self.fit_logx(grid)
#     220         else:
# --> 221             yhat, yhat_boots = self.fit_fast(grid)
#     222
#     223         # Compute the confidence interval at each grid point
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in fit_fast(self, grid)
#     240             return yhat, None
#     241
# --> 242         beta_boots = algo.bootstrap(X, y,
#     243                                     func=reg_func,
#     244                                     n_boot=self.n_boot,
#
# ~\anaconda3\lib\site-packages\seaborn\algorithms.py in bootstrap(*args, **kwargs)
#      83         resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
#      84         sample = [a.take(resampler, axis=0) for a in args]
# ---> 85         boot_dist.append(f(*sample, **func_kwargs))
#      86     return np.array(boot_dist)
#      87
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in reg_func(_x, _y)
#     232         """Low-level regression and prediction using linear algebra."""
#     233         def reg_func(_x, _y):
# --> 234             return np.linalg.pinv(_x).dot(_y)
#     235
#     236         X, y = np.c_[np.ones(len(self.x)), self.x], self.y
#
# <__array_function__ internals> in pinv(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in pinv(a, rcond, hermitian)
#    1959         return wrap(res)
#    1960     a = a.conjugate()
# -> 1961     u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    1962
#    1963     # discard small singular values
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1624
#    1625         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1626         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1627         u = u.astype(result_t, copy=False)
#    1628         s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1107867 entries, 89df2855-56eb-4706-a23b-b39363dd605a to 1f2eb52d-4f09-4921-a383-ef1bc6221789
# Data columns (total 36 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   VLF                369289 non-null  float64
#  1   VLF_PCT            369289 non-null  float64
#  2   LF                 369289 non-null  float64
#  3   LF_PCT             369289 non-null  float64
#  4   LF_NU              369289 non-null  float64
#  5   HF                 369289 non-null  float64
#  6   HF_PCT             369289 non-null  float64
#  7   HF_NU              369289 non-null  float64
#  8   TP                 369289 non-null  float64
#  9   LF_HF              369289 non-null  float64
#  10  HF_LF              369289 non-null  float64
#  11  SD1                369289 non-null  float64
#  12  SD2                369289 non-null  float64
#  13  sampen             369289 non-null  float64
#  14  higuci             369289 non-null  float64
#  15  datasetId          369289 non-null  float64
#  16  condition          369289 non-null  object
#  17  MEAN_RR            369289 non-null  float64
#  18  MEDIAN_RR          369289 non-null  float64
#  19  SDRR               369289 non-null  float64
#  20  RMSSD              369289 non-null  float64
#  21  SDSD               369289 non-null  float64
#  22  SDRR_RMSSD         369289 non-null  float64
#  23  HR                 369289 non-null  float64
#  24  pNN25              369289 non-null  float64
#  25  pNN50              369289 non-null  float64
#  26  KURT               369289 non-null  float64
#  27  SKEW               369289 non-null  float64
#  28  MEAN_REL_RR        369289 non-null  float64
#  29  MEDIAN_REL_RR      369289 non-null  float64
#  30  SDRR_REL_RR        369289 non-null  float64
#  31  RMSSD_REL_RR       369289 non-null  float64
#  32  SDSD_REL_RR        369289 non-null  float64
#  33  SDRR_RMSSD_REL_RR  369289 non-null  float64
#  34  KURT_REL_RR        369289 non-null  float64
#  35  SKEW_REL_RR        369289 non-null  float64
# dtypes: float64(35), object(1)
# memory usage: 312.7+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123099 entries, 62b75db5-bc40-4c8f-9166-daf0efcab4c2 to 0b654db0-e4d3-4ba3-b9ce-9c9291c8271e
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   VLF                41033 non-null  float64
#  1   VLF_PCT            41033 non-null  float64
#  2   LF                 41033 non-null  float64
#  3   LF_PCT             41033 non-null  float64
#  4   LF_NU              41033 non-null  float64
#  5   HF                 41033 non-null  float64
#  6   HF_PCT             41033 non-null  float64
#  7   HF_NU              41033 non-null  float64
#  8   TP                 41033 non-null  float64
#  9   LF_HF              41033 non-null  float64
#  10  HF_LF              41033 non-null  float64
#  11  SD1                41033 non-null  float64
#  12  SD2                41033 non-null  float64
#  13  sampen             41033 non-null  float64
#  14  higuci             41033 non-null  float64
#  15  datasetId          41033 non-null  float64
#  16  condition          41033 non-null  object
#  17  MEAN_RR            41033 non-null  float64
#  18  MEDIAN_RR          41033 non-null  float64
#  19  SDRR               41033 non-null  float64
#  20  RMSSD              41033 non-null  float64
#  21  SDSD               41033 non-null  float64
#  22  SDRR_RMSSD         41033 non-null  float64
#  23  pNN25              41033 non-null  float64
#  24  pNN50              41033 non-null  float64
#  25  KURT               41033 non-null  float64
#  26  SKEW               41033 non-null  float64
#  27  MEAN_REL_RR        41033 non-null  float64
#  28  MEDIAN_REL_RR      41033 non-null  float64
#  29  SDRR_REL_RR        41033 non-null  float64
#  30  RMSSD_REL_RR       41033 non-null  float64
#  31  SDSD_REL_RR        41033 non-null  float64
#  32  SDRR_RMSSD_REL_RR  41033 non-null  float64
#  33  KURT_REL_RR        41033 non-null  float64
#  34  SKEW_REL_RR        41033 non-null  float64
# dtypes: float64(34), object(1)
# memory usage: 35.8+ MB

# %%
df.index
# Out:
# Index(['89df2855-56eb-4706-a23b-b39363dd605a',
#        '80c795e4-aa56-4cc0-939c-19634b89cbb2',
#        'c2d5d102-967c-487d-88f2-8b005a449f3e',
#        '37eabc44-1349-4040-8896-0d113ad4811f',
#        'aa777a6a-7aa3-4f6e-aced-70f8691dd2b7',
#        'fe7b4ab0-42d3-48d0-8479-7b022d6af0bc',
#        'd324b1ee-aaa1-4edb-9b46-c597cb0bbd8c',
#        'cf272c21-98d8-45c1-9e2b-5ed1fe1864bd',
#        'c65dcfb0-1774-4a2a-aa45-271083faeeaa',
#        '79977df1-0e09-4873-bb31-15581002200b',
#        ...
#        'fbb319ab-c4a4-4285-ad82-a11bffd38326',
#        '4184edd7-26c4-4e3a-9ea5-f834560394df',
#        '52725ab3-1c3b-45e8-87f1-61cdf82c031f',
#        'f98fc676-ff00-4579-aae1-7ceb3b5afc7b',
#        '90657db5-2195-45a4-a5ca-f35e8ee0dfa9',
#        '028ae89f-0120-4808-955f-f6b3ecaa59b3',
#        '03f6d164-b28d-49e8-9e27-0288577408ec',
#        'fd717478-95c3-48fc-bcdc-3adebae824ab',
#        'a0fc861e-3254-4210-bd5d-37870245f7da',
#        '1f2eb52d-4f09-4921-a383-ef1bc6221789'],
#       dtype='object', name='uuid', length=1107867)

# %%
df.index.is_unique
# Out:
# False

# %%
df["condition"].value_counts(), df_test["condition"].value_counts()
# Out:
# (no stress        200082
#  interruption     105150
#  time pressure     64057
#  Name: condition, dtype: int64,
#  no stress        22158
#  interruption     11782
#  time pressure     7093
#  Name: condition, dtype: int64)

# %%
df
# Out:
#                                               VLF    VLF_PCT           LF  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  2661.894136  72.203287  1009.249419
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  2314.265450  76.975728   690.113275
# c2d5d102-967c-487d-88f2-8b005a449f3e  1373.887112  51.152225  1298.222619
# 37eabc44-1349-4040-8896-0d113ad4811f  2410.357408  70.180308  1005.981659
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  1151.177330  43.918366  1421.782051
# ...                                           ...        ...          ...
# 028ae89f-0120-4808-955f-f6b3ecaa59b3   298.009244  45.893349   313.115284
# 03f6d164-b28d-49e8-9e27-0288577408ec  1558.597883  68.405858   717.285030
# fd717478-95c3-48fc-bcdc-3adebae824ab  1950.393956  45.030641  2376.578392
# a0fc861e-3254-4210-bd5d-37870245f7da  1606.291482  54.821185  1277.128490
# 1f2eb52d-4f09-4921-a383-ef1bc6221789  1415.092653  44.537686  1701.604030
#
#                                          LF_PCT      LF_NU         HF  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  27.375666  98.485263  15.522603
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  22.954139  99.695397   2.108525
# c2d5d102-967c-487d-88f2-8b005a449f3e  48.335104  98.950472  13.769729
# 37eabc44-1349-4040-8896-0d113ad4811f  29.290305  98.224706  18.181913
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  54.242160  96.720007  48.215822
# ...                                         ...        ...        ...
# 028ae89f-0120-4808-955f-f6b3ecaa59b3  48.219676  89.119683  38.227175
# 03f6d164-b28d-49e8-9e27-0288577408ec  31.481178  99.642453   2.573834
# fd717478-95c3-48fc-bcdc-3adebae824ab  54.870376  99.819930   4.287216
# a0fc861e-3254-4210-bd5d-37870245f7da  43.587168  96.477005  46.636158
# 1f2eb52d-4f09-4921-a383-ef1bc6221789  53.555155  96.561342  60.596026
#
#                                         HF_PCT      HF_NU           TP  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a  0.421047   1.514737  3686.666157
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  0.070133   0.304603  3006.487251
# c2d5d102-967c-487d-88f2-8b005a449f3e  0.512671   1.049528  2685.879461
# 37eabc44-1349-4040-8896-0d113ad4811f  0.529387   1.775294  3434.520980
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  1.839473   3.279993  2621.175204
# ...                                        ...        ...          ...
# 028ae89f-0120-4808-955f-f6b3ecaa59b3  5.886975  10.880317   649.351702
# 03f6d164-b28d-49e8-9e27-0288577408ec  0.112964   0.357547  2278.456746
# fd717478-95c3-48fc-bcdc-3adebae824ab  0.098983   0.180070  4331.259564
# a0fc861e-3254-4210-bd5d-37870245f7da  1.591647   3.522995  2930.056129
# 1f2eb52d-4f09-4921-a383-ef1bc6221789  1.907159   3.438658  3177.292709
#
#                                            LF_HF  ...      KURT      SKEW  \
# uuid                                              ...
# 89df2855-56eb-4706-a23b-b39363dd605a   65.018055  ... -0.856554  0.335218
# 80c795e4-aa56-4cc0-939c-19634b89cbb2  327.296635  ... -0.408190 -0.155286
# c2d5d102-967c-487d-88f2-8b005a449f3e   94.280910  ...  0.351789 -0.656813
# 37eabc44-1349-4040-8896-0d113ad4811f   55.328701  ... -0.504947 -0.386138
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7   29.487873  ... -0.548408 -0.154252
# ...                                          ...  ...       ...       ...
# 028ae89f-0120-4808-955f-f6b3ecaa59b3    8.190908  ...  1.007321  0.075965
# 03f6d164-b28d-49e8-9e27-0288577408ec  278.683532  ...  0.248964  0.167716
# fd717478-95c3-48fc-bcdc-3adebae824ab  554.340761  ... -0.429686 -0.075321
# a0fc861e-3254-4210-bd5d-37870245f7da   27.384942  ...  0.600389 -0.634762
# 1f2eb52d-4f09-4921-a383-ef1bc6221789   28.081116  ... -0.397950 -0.191514
#
#                                       MEAN_REL_RR  MEDIAN_REL_RR  SDRR_REL_RR  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a    -0.000203      -0.000179     0.017080
# 80c795e4-aa56-4cc0-939c-19634b89cbb2    -0.000059       0.000611     0.013978
# c2d5d102-967c-487d-88f2-8b005a449f3e    -0.000011      -0.000263     0.018539
# 37eabc44-1349-4040-8896-0d113ad4811f     0.000112       0.000494     0.017761
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7    -0.000100      -0.002736     0.023715
# ...                                           ...            ...          ...
# 028ae89f-0120-4808-955f-f6b3ecaa59b3     0.000015       0.000083     0.013352
# 03f6d164-b28d-49e8-9e27-0288577408ec    -0.000110       0.000046     0.014014
# fd717478-95c3-48fc-bcdc-3adebae824ab    -0.000216      -0.002236     0.022705
# a0fc861e-3254-4210-bd5d-37870245f7da     0.000024      -0.001354     0.021549
# 1f2eb52d-4f09-4921-a383-ef1bc6221789    -0.000015      -0.002479     0.025374
#
#                                       RMSSD_REL_RR  SDSD_REL_RR  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a      0.007969     0.007969
# 80c795e4-aa56-4cc0-939c-19634b89cbb2      0.004769     0.004769
# c2d5d102-967c-487d-88f2-8b005a449f3e      0.008716     0.008716
# 37eabc44-1349-4040-8896-0d113ad4811f      0.008660     0.008660
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7      0.013055     0.013055
# ...                                            ...          ...
# 028ae89f-0120-4808-955f-f6b3ecaa59b3      0.008732     0.008732
# 03f6d164-b28d-49e8-9e27-0288577408ec      0.006317     0.006317
# fd717478-95c3-48fc-bcdc-3adebae824ab      0.009494     0.009494
# a0fc861e-3254-4210-bd5d-37870245f7da      0.011376     0.011376
# 1f2eb52d-4f09-4921-a383-ef1bc6221789      0.013519     0.013519
#
#                                       SDRR_RMSSD_REL_RR  KURT_REL_RR  \
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a           2.143342    -0.856554
# 80c795e4-aa56-4cc0-939c-19634b89cbb2           2.930855    -0.408190
# c2d5d102-967c-487d-88f2-8b005a449f3e           2.127053     0.351789
# 37eabc44-1349-4040-8896-0d113ad4811f           2.050988    -0.504947
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7           1.816544    -0.548408
# ...                                                 ...          ...
# 028ae89f-0120-4808-955f-f6b3ecaa59b3           1.529068     1.007321
# 03f6d164-b28d-49e8-9e27-0288577408ec           2.218313     0.248964
# fd717478-95c3-48fc-bcdc-3adebae824ab           2.391601    -0.429686
# a0fc861e-3254-4210-bd5d-37870245f7da           1.894304     0.600389
# 1f2eb52d-4f09-4921-a383-ef1bc6221789           1.876939    -0.397950
#
#                                       SKEW_REL_RR
# uuid
# 89df2855-56eb-4706-a23b-b39363dd605a     0.335218
# 80c795e4-aa56-4cc0-939c-19634b89cbb2    -0.155286
# c2d5d102-967c-487d-88f2-8b005a449f3e    -0.656813
# 37eabc44-1349-4040-8896-0d113ad4811f    -0.386138
# aa777a6a-7aa3-4f6e-aced-70f8691dd2b7    -0.154252
# ...                                           ...
# 028ae89f-0120-4808-955f-f6b3ecaa59b3     0.075965
# 03f6d164-b28d-49e8-9e27-0288577408ec     0.167716
# fd717478-95c3-48fc-bcdc-3adebae824ab    -0.075321
# a0fc861e-3254-4210-bd5d-37870245f7da    -0.634762
# 1f2eb52d-4f09-4921-a383-ef1bc6221789    -0.191514
#
# [369289 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 369289 entries, 89df2855-56eb-4706-a23b-b39363dd605a to 1f2eb52d-4f09-4921-a383-ef1bc6221789
# Data columns (total 34 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   VLF                369289 non-null  float64
#  1   VLF_PCT            369289 non-null  float64
#  2   LF                 369289 non-null  float64
#  3   LF_PCT             369289 non-null  float64
#  4   LF_NU              369289 non-null  float64
#  5   HF                 369289 non-null  float64
#  6   HF_PCT             369289 non-null  float64
#  7   HF_NU              369289 non-null  float64
#  8   TP                 369289 non-null  float64
#  9   LF_HF              369289 non-null  float64
#  10  HF_LF              369289 non-null  float64
#  11  SD1                369289 non-null  float64
#  12  SD2                369289 non-null  float64
#  13  sampen             369289 non-null  float64
#  14  higuci             369289 non-null  float64
#  15  MEAN_RR            369289 non-null  float64
#  16  MEDIAN_RR          369289 non-null  float64
#  17  SDRR               369289 non-null  float64
#  18  RMSSD              369289 non-null  float64
#  19  SDSD               369289 non-null  float64
#  20  SDRR_RMSSD         369289 non-null  float64
#  21  HR                 369289 non-null  float64
#  22  pNN25              369289 non-null  float64
#  23  pNN50              369289 non-null  float64
#  24  KURT               369289 non-null  float64
#  25  SKEW               369289 non-null  float64
#  26  MEAN_REL_RR        369289 non-null  float64
#  27  MEDIAN_REL_RR      369289 non-null  float64
#  28  SDRR_REL_RR        369289 non-null  float64
#  29  RMSSD_REL_RR       369289 non-null  float64
#  30  SDSD_REL_RR        369289 non-null  float64
#  31  SDRR_RMSSD_REL_RR  369289 non-null  float64
#  32  KURT_REL_RR        369289 non-null  float64
#  33  SKEW_REL_RR        369289 non-null  float64
# dtypes: float64(34)
# memory usage: 98.6+ MB

# %%
df=df.drop(["datasetId","condition","uuid"],axis=1)

df_test=df_test.drop(["datasetId"],axis=1)

# %%
#df=df[:10000]

# %%
for each in df.columns:
    sns.kdeplot(df[each])

# %%
df.isna().any().all(),df_test.isna().any().all()
# Out:
# (True, True)

# %%
df_dist=df.describe()
df_dist.columns
# Out:
# Index(['VLF', 'VLF_PCT', 'LF', 'LF_PCT', 'LF_NU', 'HF', 'HF_PCT', 'HF_NU',
#        'TP', 'LF_HF', 'HF_LF', 'SD1', 'SD2', 'sampen', 'higuci', 'MEAN_RR',
#        'MEDIAN_RR', 'SDRR', 'RMSSD', 'SDSD', 'SDRR_RMSSD', 'HR', 'pNN25',
#        'pNN50', 'KURT', 'SKEW', 'MEAN_REL_RR', 'MEDIAN_REL_RR', 'SDRR_REL_RR',
#        'RMSSD_REL_RR', 'SDSD_REL_RR', 'SDRR_RMSSD_REL_RR', 'KURT_REL_RR',
#        'SKEW_REL_RR'],
#       dtype='object')

# %%
df.shape

# %%
df.index

# %%
col="HF"
print(df[col].shape)
Q1=df_dist[col]["25%"]
Q3=df_dist[col]["75%"]
#temp=pd.concat([df[df[col]<Q1],df[df[col]<Q1]],axis=1)[col]
#df[(df[col]>Q3) & (df[col]<Q1)]
series1=df[df[col]<Q1][col]
print(series1.shape)
series2=df[df[col]>Q3][col]
print(series2.shape)
series3=series1.append(series2)

# %%
total=df.shape[0]
df_outliers={}
df_inliers={}
for col in df_dist.columns:
    temp=df[col]
    Q1=df_dist[col]["25%"]
    Q3=df_dist[col]["75%"]
    series1=df[df[col]<Q1][col]
    #print(series1.shape)
    series2=df[df[col]>Q3][col]
    #print(series2.shape)
    series3=series1.append(series2)
    df_outliers.update({col:series3})
    df_inliers.update({col : df.drop(index=series3.index)[col]})
    print(series3.shape[0])
    print(col, " : ",series3.shape[0]*100/total," % ","\n")

# %%
df_outliers["LF_PCT"],df_inliers["LF_PCT"]

# %%
df_outliers["HR"],df_inliers["HR"]

# %%
df_outliers["HF"]
# Out:
# uuid
# 80c795e4-aa56-4cc0-939c-19634b89cbb2      2.108525
# d324b1ee-aaa1-4edb-9b46-c597cb0bbd8c      1.489796
# 79977df1-0e09-4873-bb31-15581002200b      2.572459
# ba6a9a9b-5c8b-4c9a-be89-0283898b2d96      8.920651
# 28f8941e-e36a-4f5c-9cdd-9f1e715b05ed      9.918353
#                                            ...
# e1fb60d2-95fa-40c3-be6b-380799ac3df8    135.766749
# 7e0a9b7c-aab2-4a3c-88c8-d3c326a0ca85    135.162751
# 404b56c0-d6f2-4a67-9d3a-698f4a6be270     61.080993
# a0fc861e-3254-4210-bd5d-37870245f7da     46.636158
# 1f2eb52d-4f09-4921-a383-ef1bc6221789     60.596026
# Name: HF, Length: 184644, dtype: float64

# %%
for each in df_outliers.keys():
    sns.displot(df_outliers[each])
# Out:
# C:\Users\Sheshank_Joshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\seaborn\axisgrid.py:392: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)

# %%
for each in df1.uuid:
    if each in df2.uuid:
        pass
    else:
        print(each)

# %%
for each in df2.uuid:
    if each in df3.uuid:
        pass
    else:
        print(each)

# %%
print(set(df1.uuid)-set(df2.uuid))
print(set(df2.uuid)-set(df1.uuid))
print(set(df2.uuid)-set(df3.uuid))
print(set(df3.uuid)-set(df2.uuid))
# Out:
# set()
# set()
# set()
# set()

# %%
df.drop("uuid",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-fd30deee5cbd> in <module>
# ----> 1 df.drop("uuid",axis=1)
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['uuid'] not found in axis"

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.cov(),annot=True)
plt.show()

# %%
df=pd.get_dummies(data=df,drop_first=True)
df_test=pd.get_dummies(data=df_test,drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-24-33a46b6eb7f6> in <module>
# ----> 1 df=pd.get_dummies(data=df,drop_first=True)
#       2 df_test=pd.get_dummies(data=df_test,drop_first=True)
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     891         for (col, pre, sep) in zip(data_to_encode.items(), prefix, prefix_sep):
#     892             # col is (column_name, column), use just column data here
# --> 893             dummy = _get_dummies_1d(
#     894                 col[1],
#     895                 prefix=pre,
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\pandas\core\reshape\reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#    1007
#    1008     else:
# -> 1009         dummy_mat = np.eye(number_of_cols, dtype=dtype).take(codes, axis=0)
#    1010
#    1011         if not dummy_na:
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\numpy\lib\twodim_base.py in eye(N, M, k, dtype, order)
#     199     if M is None:
#     200         M = N
# --> 201     m = zeros((N, M), dtype=dtype, order=order)
#     202     if k >= M:
#     203         return m
#
# MemoryError: Unable to allocate 127. GiB for an array with shape (369289, 369289) and data type uint8

# %%
from tensorflow.keras.layers import Activation, Dense, Flatten
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Reshape, BatchNormalization, Dropout
from sklearn.metrics import accuracy_score
from tensorflow.keras.callbacks import EarlyStopping

# %%
import tensorflow
import tensorflow.keras as k
###################################################################
#Regressional Neural Network
###################################################################
model_reg_1=Sequential()
model_reg_1.add(BatchNormalization(input_shape=(35,)))
model_reg_1.add(Flatten())
model_reg_1.add(Dense(70,activation="relu",kernel_initializer='random_uniform',bias_initializer='zeros',kernel_regularizer="l2",bias_regularizer="l2"))
model_reg_1.add(Dropout(0.2, input_shape=(50,)))
model_reg_1.add(Dense(35,activation="relu",kernel_initializer='random_uniform',bias_initializer='zeros',kernel_regularizer="l2",bias_regularizer="l2"))
model_reg_1.add(Dropout(0.2, input_shape=(50,)))
model_reg_1.add(Dense(15,activation="relu",kernel_initializer='random_uniform',bias_initializer='zeros',kernel_regularizer="l2",bias_regularizer="l2"))
model_reg_1.add(Dropout(0.5, input_shape=(50,)))
model_reg_1.add(Dense(5,activation="relu",kernel_initializer='random_uniform',bias_initializer='zeros',kernel_regularizer="l2",bias_regularizer="l2"))
model_reg_1.add(Dropout(0.5, input_shape=(50,)))
#model_reg_1.add(Dense(12,activation="relu",kernel_initializer='random_uniform',bias_initializer='zeros',kernel_regularizer="l2",bias_regularizer="l2"))
#model_reg_1.add(Dropout(0.5, input_shape=(30,)))
#model_reg_1.add(Dense(36,activation="relu",kernel_initializer='random_uniform',bias_initializer='zeros',kernel_regularizer="l2",bias_regularizer="l2"))
model_reg_1.add(Dense(1))
sgd = optimizers.SGD(lr = 0.01,momentum=0.4)
model_reg_1.compile(optimizer = sgd, loss = 'mae', metrics =tf.keras.metrics.mean_absolute_error)
###################################################################
#
###################################################################

callback = EarlyStopping(monitor='loss', patience=3)

# %%
model_reg_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 35)                140
# _________________________________________________________________
# flatten (Flatten)            (None, 35)                0
# _________________________________________________________________
# dense (Dense)                (None, 70)                2520
# _________________________________________________________________
# dropout (Dropout)            (None, 70)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 35)                2485
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 35)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                540
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 80
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 5,771
# Trainable params: 5,701
# Non-trainable params: 70
# _________________________________________________________________

# %%
t=time.time()
history_reg_1=model_reg_1.fit(df.drop("HR",axis=1),df["HR"],batch_size=2000, validation_split=0.3,epochs = 200,callbacks=[callback])
# Out:
# Epoch 1/200
# 130/130 [==============================] - 2s 11ms/step - loss: 72.4070 - mean_absolute_error: 72.3535 - val_loss: 49.7318 - val_mean_absolute_error: 49.5111
# Epoch 2/200
# 130/130 [==============================] - 1s 4ms/step - loss: 38.7702 - mean_absolute_error: 38.4571 - val_loss: 22.6513 - val_mean_absolute_error: 22.2286
# Epoch 3/200
# 130/130 [==============================] - 1s 4ms/step - loss: 30.0948 - mean_absolute_error: 29.6638 - val_loss: 20.2014 - val_mean_absolute_error: 19.7582
# Epoch 4/200
# 130/130 [==============================] - 1s 4ms/step - loss: 29.2883 - mean_absolute_error: 28.8441 - val_loss: 18.7765 - val_mean_absolute_error: 18.3325
# Epoch 5/200
# 130/130 [==============================] - 1s 4ms/step - loss: 28.5222 - mean_absolute_error: 28.0781 - val_loss: 18.5312 - val_mean_absolute_error: 18.0850
# Epoch 6/200
# 130/130 [==============================] - 1s 4ms/step - loss: 27.5013 - mean_absolute_error: 27.0512 - val_loss: 17.1889 - val_mean_absolute_error: 16.7298
# Epoch 7/200
# 130/130 [==============================] - 1s 4ms/step - loss: 26.7725 - mean_absolute_error: 26.3155 - val_loss: 17.0561 - val_mean_absolute_error: 16.6038
# Epoch 8/200
# 130/130 [==============================] - 1s 4ms/step - loss: 26.3289 - mean_absolute_error: 25.8807 - val_loss: 16.9269 - val_mean_absolute_error: 16.4884
# Epoch 9/200
# 130/130 [==============================] - 1s 4ms/step - loss: 26.0316 - mean_absolute_error: 25.5973 - val_loss: 17.0087 - val_mean_absolute_error: 16.5886
# Epoch 10/200
# 130/130 [==============================] - 1s 4ms/step - loss: 25.7086 - mean_absolute_error: 25.2908 - val_loss: 15.7747 - val_mean_absolute_error: 15.3674
# Epoch 11/200
# 130/130 [==============================] - 1s 4ms/step - loss: 25.3147 - mean_absolute_error: 24.9137 - val_loss: 16.6872 - val_mean_absolute_error: 16.3010
# Epoch 12/200
# 130/130 [==============================] - 1s 4ms/step - loss: 24.9701 - mean_absolute_error: 24.5862 - val_loss: 16.0621 - val_mean_absolute_error: 15.6897
# Epoch 13/200
# 130/130 [==============================] - 1s 4ms/step - loss: 24.6356 - mean_absolute_error: 24.2669 - val_loss: 16.1266 - val_mean_absolute_error: 15.7699
# Epoch 14/200
# 130/130 [==============================] - 1s 4ms/step - loss: 24.2794 - mean_absolute_error: 23.9252 - val_loss: 15.4265 - val_mean_absolute_error: 15.0819
# Epoch 15/200
# 130/130 [==============================] - 1s 4ms/step - loss: 23.9757 - mean_absolute_error: 23.6350 - val_loss: 15.7265 - val_mean_absolute_error: 15.3979
# Epoch 16/200
# 130/130 [==============================] - 1s 4ms/step - loss: 23.6321 - mean_absolute_error: 23.3053 - val_loss: 15.3670 - val_mean_absolute_error: 15.0504
# Epoch 17/200
# 130/130 [==============================] - 1s 4ms/step - loss: 23.2230 - mean_absolute_error: 22.9087 - val_loss: 15.2873 - val_mean_absolute_error: 14.9824
# Epoch 18/200
# 130/130 [==============================] - 1s 4ms/step - loss: 22.9800 - mean_absolute_error: 22.6772 - val_loss: 14.9213 - val_mean_absolute_error: 14.6283
# Epoch 19/200
# 130/130 [==============================] - 1s 4ms/step - loss: 22.7222 - mean_absolute_error: 22.4316 - val_loss: 14.8483 - val_mean_absolute_error: 14.5673
# Epoch 20/200
# 130/130 [==============================] - 1s 4ms/step - loss: 22.3075 - mean_absolute_error: 22.0276 - val_loss: 14.2290 - val_mean_absolute_error: 13.9565
# Epoch 21/200
# 130/130 [==============================] - 1s 4ms/step - loss: 22.0369 - mean_absolute_error: 21.7667 - val_loss: 14.0385 - val_mean_absolute_error: 13.7762
# Epoch 22/200
# 130/130 [==============================] - 1s 4ms/step - loss: 21.7794 - mean_absolute_error: 21.5191 - val_loss: 13.6486 - val_mean_absolute_error: 13.3949
# Epoch 23/200
# 130/130 [==============================] - 1s 4ms/step - loss: 21.4138 - mean_absolute_error: 21.1623 - val_loss: 13.6070 - val_mean_absolute_error: 13.3617
# Epoch 24/200
# 130/130 [==============================] - 1s 4ms/step - loss: 21.1295 - mean_absolute_error: 20.8869 - val_loss: 12.9180 - val_mean_absolute_error: 12.6804
# Epoch 25/200
# 130/130 [==============================] - 1s 4ms/step - loss: 20.8220 - mean_absolute_error: 20.5877 - val_loss: 12.6850 - val_mean_absolute_error: 12.4565
# Epoch 26/200
# 130/130 [==============================] - 1s 4ms/step - loss: 20.4674 - mean_absolute_error: 20.2418 - val_loss: 12.8483 - val_mean_absolute_error: 12.6288
# Epoch 27/200
# 130/130 [==============================] - 1s 4ms/step - loss: 20.1578 - mean_absolute_error: 19.9400 - val_loss: 12.5800 - val_mean_absolute_error: 12.3675
# Epoch 28/200
# 130/130 [==============================] - 1s 4ms/step - loss: 19.8648 - mean_absolute_error: 19.6542 - val_loss: 12.1638 - val_mean_absolute_error: 11.9581
# Epoch 29/200
# 130/130 [==============================] - 1s 4ms/step - loss: 19.4893 - mean_absolute_error: 19.2864 - val_loss: 12.0151 - val_mean_absolute_error: 11.8160
# Epoch 30/200
# 130/130 [==============================] - 1s 4ms/step - loss: 19.2090 - mean_absolute_error: 19.0121 - val_loss: 11.7930 - val_mean_absolute_error: 11.6009
# Epoch 31/200
# 130/130 [==============================] - 1s 4ms/step - loss: 18.9239 - mean_absolute_error: 18.7336 - val_loss: 11.9302 - val_mean_absolute_error: 11.7448
# Epoch 32/200
# 130/130 [==============================] - 1s 4ms/step - loss: 18.5349 - mean_absolute_error: 18.3508 - val_loss: 11.4176 - val_mean_absolute_error: 11.2379
# Epoch 33/200
# 130/130 [==============================] - 1s 4ms/step - loss: 18.2132 - mean_absolute_error: 18.0352 - val_loss: 11.5642 - val_mean_absolute_error: 11.3916
# Epoch 34/200
# 130/130 [==============================] - 1s 4ms/step - loss: 17.9174 - mean_absolute_error: 17.7456 - val_loss: 10.5226 - val_mean_absolute_error: 10.3539
# Epoch 35/200
# 130/130 [==============================] - 1s 4ms/step - loss: 17.6192 - mean_absolute_error: 17.4532 - val_loss: 10.7915 - val_mean_absolute_error: 10.6290
# Epoch 36/200
# 130/130 [==============================] - 1s 4ms/step - loss: 17.3583 - mean_absolute_error: 17.1977 - val_loss: 10.7127 - val_mean_absolute_error: 10.5556
# Epoch 37/200
# 130/130 [==============================] - 1s 4ms/step - loss: 17.0306 - mean_absolute_error: 16.8749 - val_loss: 10.5695 - val_mean_absolute_error: 10.4179
# Epoch 38/200
# 130/130 [==============================] - 0s 4ms/step - loss: 16.6591 - mean_absolute_error: 16.5089 - val_loss: 10.3832 - val_mean_absolute_error: 10.2361
# Epoch 39/200
# 130/130 [==============================] - 1s 4ms/step - loss: 16.3543 - mean_absolute_error: 16.2086 - val_loss: 9.5590 - val_mean_absolute_error: 9.4155
# Epoch 40/200
# 130/130 [==============================] - 1s 4ms/step - loss: 16.0908 - mean_absolute_error: 15.9499 - val_loss: 10.0709 - val_mean_absolute_error: 9.9331
# Epoch 41/200
# 130/130 [==============================] - 1s 4ms/step - loss: 15.6780 - mean_absolute_error: 15.5413 - val_loss: 9.8692 - val_mean_absolute_error: 9.7362
# Epoch 42/200
# 130/130 [==============================] - 1s 4ms/step - loss: 15.4411 - mean_absolute_error: 15.3086 - val_loss: 9.3074 - val_mean_absolute_error: 9.1774
# Epoch 43/200
# 130/130 [==============================] - 1s 4ms/step - loss: 15.1322 - mean_absolute_error: 15.0035 - val_loss: 9.3101 - val_mean_absolute_error: 9.1846
# Epoch 44/200
# 130/130 [==============================] - 1s 4ms/step - loss: 14.8535 - mean_absolute_error: 14.7288 - val_loss: 8.9443 - val_mean_absolute_error: 8.8222
# Epoch 45/200
# 130/130 [==============================] - 1s 4ms/step - loss: 14.4533 - mean_absolute_error: 14.3324 - val_loss: 8.7756 - val_mean_absolute_error: 8.6581
# Epoch 46/200
# 130/130 [==============================] - 1s 4ms/step - loss: 14.1932 - mean_absolute_error: 14.0765 - val_loss: 8.5078 - val_mean_absolute_error: 8.3937
# Epoch 47/200
# 130/130 [==============================] - 1s 4ms/step - loss: 13.8529 - mean_absolute_error: 13.7398 - val_loss: 8.0053 - val_mean_absolute_error: 7.8931
# Epoch 48/200
# 130/130 [==============================] - 1s 4ms/step - loss: 13.6226 - mean_absolute_error: 13.5125 - val_loss: 8.5732 - val_mean_absolute_error: 8.4668
# Epoch 49/200
# 130/130 [==============================] - 1s 4ms/step - loss: 13.3079 - mean_absolute_error: 13.2014 - val_loss: 8.1007 - val_mean_absolute_error: 7.9967
# Epoch 50/200
# 130/130 [==============================] - 1s 4ms/step - loss: 12.9605 - mean_absolute_error: 12.8575 - val_loss: 8.0659 - val_mean_absolute_error: 7.9657
# Epoch 51/200
# 130/130 [==============================] - 1s 4ms/step - loss: 12.6653 - mean_absolute_error: 12.5656 - val_loss: 7.8914 - val_mean_absolute_error: 7.7944
# Epoch 52/200
# 130/130 [==============================] - 1s 4ms/step - loss: 12.3810 - mean_absolute_error: 12.2841 - val_loss: 7.7314 - val_mean_absolute_error: 7.6376
# Epoch 53/200
# 130/130 [==============================] - 1s 4ms/step - loss: 12.1138 - mean_absolute_error: 12.0197 - val_loss: 7.6063 - val_mean_absolute_error: 7.5149
# Epoch 54/200
# 130/130 [==============================] - 1s 4ms/step - loss: 11.7634 - mean_absolute_error: 11.6722 - val_loss: 6.8970 - val_mean_absolute_error: 6.8068
# Epoch 55/200
# 130/130 [==============================] - 1s 4ms/step - loss: 11.4283 - mean_absolute_error: 11.3393 - val_loss: 7.4505 - val_mean_absolute_error: 7.3646
# Epoch 56/200
# 130/130 [==============================] - 1s 4ms/step - loss: 11.1528 - mean_absolute_error: 11.0666 - val_loss: 7.0122 - val_mean_absolute_error: 6.9277
# Epoch 57/200
# 130/130 [==============================] - 1s 4ms/step - loss: 10.8419 - mean_absolute_error: 10.7577 - val_loss: 6.7878 - val_mean_absolute_error: 6.7052
# Epoch 58/200
# 130/130 [==============================] - 1s 4ms/step - loss: 10.5554 - mean_absolute_error: 10.4733 - val_loss: 6.5751 - val_mean_absolute_error: 6.4953
# Epoch 59/200
# 130/130 [==============================] - 1s 4ms/step - loss: 10.2309 - mean_absolute_error: 10.1512 - val_loss: 6.1379 - val_mean_absolute_error: 6.0595
# Epoch 60/200
# 130/130 [==============================] - 1s 4ms/step - loss: 9.9138 - mean_absolute_error: 9.8359 - val_loss: 5.5865 - val_mean_absolute_error: 5.5091
# Epoch 61/200
# 130/130 [==============================] - 1s 4ms/step - loss: 9.6482 - mean_absolute_error: 9.5717 - val_loss: 5.8624 - val_mean_absolute_error: 5.7875
# Epoch 62/200
# 130/130 [==============================] - 1s 4ms/step - loss: 9.3646 - mean_absolute_error: 9.2896 - val_loss: 6.0052 - val_mean_absolute_error: 5.9317
# Epoch 63/200
# 130/130 [==============================] - 1s 4ms/step - loss: 9.0679 - mean_absolute_error: 8.9940 - val_loss: 4.7984 - val_mean_absolute_error: 4.7245
# Epoch 64/200
# 130/130 [==============================] - 1s 4ms/step - loss: 8.8055 - mean_absolute_error: 8.7326 - val_loss: 5.6502 - val_mean_absolute_error: 5.5779
# Epoch 65/200
# 130/130 [==============================] - 1s 4ms/step - loss: 8.5205 - mean_absolute_error: 8.4478 - val_loss: 5.3184 - val_mean_absolute_error: 5.2455
# Epoch 66/200
# 130/130 [==============================] - 1s 4ms/step - loss: 8.1968 - mean_absolute_error: 8.1239 - val_loss: 4.8845 - val_mean_absolute_error: 4.8105
# Epoch 67/200
# 130/130 [==============================] - 1s 4ms/step - loss: 7.9395 - mean_absolute_error: 7.8661 - val_loss: 4.6758 - val_mean_absolute_error: 4.6017
# Epoch 68/200
# 130/130 [==============================] - 0s 4ms/step - loss: 7.6940 - mean_absolute_error: 7.6201 - val_loss: 5.1582 - val_mean_absolute_error: 5.0840
# Epoch 69/200
# 130/130 [==============================] - 1s 4ms/step - loss: 7.4358 - mean_absolute_error: 7.3606 - val_loss: 4.1230 - val_mean_absolute_error: 4.0463
# Epoch 70/200
# 130/130 [==============================] - 1s 4ms/step - loss: 7.2231 - mean_absolute_error: 7.1466 - val_loss: 4.7192 - val_mean_absolute_error: 4.6419
# Epoch 71/200
# 130/130 [==============================] - 1s 4ms/step - loss: 6.9569 - mean_absolute_error: 6.8787 - val_loss: 4.7293 - val_mean_absolute_error: 4.6499
# Epoch 72/200
# 130/130 [==============================] - 1s 4ms/step - loss: 6.7098 - mean_absolute_error: 6.6291 - val_loss: 4.4886 - val_mean_absolute_error: 4.4062
# Epoch 73/200
# 130/130 [==============================] - 1s 4ms/step - loss: 6.5236 - mean_absolute_error: 6.4406 - val_loss: 4.4231 - val_mean_absolute_error: 4.3389
# Epoch 74/200
# 130/130 [==============================] - 1s 4ms/step - loss: 6.3389 - mean_absolute_error: 6.2538 - val_loss: 4.4833 - val_mean_absolute_error: 4.3969
# Epoch 75/200
# 130/130 [==============================] - 1s 4ms/step - loss: 6.1372 - mean_absolute_error: 6.0497 - val_loss: 3.3862 - val_mean_absolute_error: 3.2973
# Epoch 76/200
# 130/130 [==============================] - 1s 4ms/step - loss: 5.9742 - mean_absolute_error: 5.8851 - val_loss: 3.8265 - val_mean_absolute_error: 3.7363
# Epoch 77/200
# 130/130 [==============================] - 1s 4ms/step - loss: 5.8034 - mean_absolute_error: 5.7127 - val_loss: 3.4561 - val_mean_absolute_error: 3.3642
# Epoch 78/200
# 130/130 [==============================] - 1s 4ms/step - loss: 5.6651 - mean_absolute_error: 5.5732 - val_loss: 4.1146 - val_mean_absolute_error: 4.0227
# Epoch 79/200
# 130/130 [==============================] - 1s 4ms/step - loss: 5.5024 - mean_absolute_error: 5.4101 - val_loss: 2.7657 - val_mean_absolute_error: 2.6722
# Epoch 80/200
# 130/130 [==============================] - 1s 4ms/step - loss: 5.4212 - mean_absolute_error: 5.3285 - val_loss: 3.6616 - val_mean_absolute_error: 3.5691
# Epoch 81/200
# 130/130 [==============================] - 1s 4ms/step - loss: 5.2844 - mean_absolute_error: 5.1913 - val_loss: 3.2340 - val_mean_absolute_error: 3.1406
# Epoch 82/200
# 130/130 [==============================] - 1s 4ms/step - loss: 5.1848 - mean_absolute_error: 5.0914 - val_loss: 3.5521 - val_mean_absolute_error: 3.4588
# Epoch 83/200
# 130/130 [==============================] - 1s 4ms/step - loss: 5.1021 - mean_absolute_error: 5.0083 - val_loss: 2.5576 - val_mean_absolute_error: 2.4623
# Epoch 84/200
# 130/130 [==============================] - 1s 4ms/step - loss: 5.0104 - mean_absolute_error: 4.9161 - val_loss: 3.2543 - val_mean_absolute_error: 3.1602
# Epoch 85/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.9579 - mean_absolute_error: 4.8634 - val_loss: 3.5606 - val_mean_absolute_error: 3.4663
# Epoch 86/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.8907 - mean_absolute_error: 4.7963 - val_loss: 3.1066 - val_mean_absolute_error: 3.0127
# Epoch 87/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.8286 - mean_absolute_error: 4.7342 - val_loss: 3.1224 - val_mean_absolute_error: 3.0281
# Epoch 88/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.7730 - mean_absolute_error: 4.6784 - val_loss: 2.9357 - val_mean_absolute_error: 2.8405
# Epoch 89/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.7401 - mean_absolute_error: 4.6453 - val_loss: 3.0412 - val_mean_absolute_error: 2.9461
# Epoch 90/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.6740 - mean_absolute_error: 4.5790 - val_loss: 3.0261 - val_mean_absolute_error: 2.9318
# Epoch 91/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.6377 - mean_absolute_error: 4.5430 - val_loss: 2.9491 - val_mean_absolute_error: 2.8538
# Epoch 92/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.6071 - mean_absolute_error: 4.5121 - val_loss: 3.0342 - val_mean_absolute_error: 2.9391
# Epoch 93/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.5756 - mean_absolute_error: 4.4808 - val_loss: 2.7649 - val_mean_absolute_error: 2.6706
# Epoch 94/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.5715 - mean_absolute_error: 4.4773 - val_loss: 3.4481 - val_mean_absolute_error: 3.3552
# Epoch 95/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.5471 - mean_absolute_error: 4.4534 - val_loss: 2.7824 - val_mean_absolute_error: 2.6879
# Epoch 96/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.5415 - mean_absolute_error: 4.4478 - val_loss: 2.2600 - val_mean_absolute_error: 2.1658
# Epoch 97/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4968 - mean_absolute_error: 4.4038 - val_loss: 3.0749 - val_mean_absolute_error: 2.9823
# Epoch 98/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4974 - mean_absolute_error: 4.4048 - val_loss: 3.0201 - val_mean_absolute_error: 2.9283
# Epoch 99/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4897 - mean_absolute_error: 4.3979 - val_loss: 2.7310 - val_mean_absolute_error: 2.6391
# Epoch 100/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4794 - mean_absolute_error: 4.3877 - val_loss: 3.3797 - val_mean_absolute_error: 3.2892
# Epoch 101/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4605 - mean_absolute_error: 4.3693 - val_loss: 2.7223 - val_mean_absolute_error: 2.6318
# Epoch 102/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4447 - mean_absolute_error: 4.3544 - val_loss: 2.5502 - val_mean_absolute_error: 2.4602
# Epoch 103/200
# 130/130 [==============================] - 0s 4ms/step - loss: 4.4646 - mean_absolute_error: 4.3754 - val_loss: 3.2116 - val_mean_absolute_error: 3.1229
# Epoch 104/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4537 - mean_absolute_error: 4.3650 - val_loss: 3.2066 - val_mean_absolute_error: 3.1190
# Epoch 105/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4399 - mean_absolute_error: 4.3518 - val_loss: 2.8170 - val_mean_absolute_error: 2.7292
# Epoch 106/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4405 - mean_absolute_error: 4.3531 - val_loss: 2.7489 - val_mean_absolute_error: 2.6615
# Epoch 107/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4471 - mean_absolute_error: 4.3600 - val_loss: 2.8899 - val_mean_absolute_error: 2.8034
# Epoch 108/200
# 130/130 [==============================] - 1s 4ms/step - loss: 4.4504 - mean_absolute_error: 4.3642 - val_loss: 2.5548 - val_mean_absolute_error: 2.4685

# %%
print(time.time()-t)
# Out:
# 79.21059346199036

# %%
df_test
# Out:
#                                                             VLF    VLF_PCT  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...  1868.532278  76.511189
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...   568.742845  26.301350
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...  2101.871207  75.836461
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...  5757.544433  90.562305
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...   964.696325  70.256575
# ...                                                         ...        ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...  1690.286178  75.534076
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...  1335.773510  76.550710
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...  1762.102170  47.355959
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...   317.702587  57.455826
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...  1706.035626  69.983613
#
#                                                              LF     LF_PCT  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...   570.643114  23.366245
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...  1553.971621  71.862973
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...   655.175895  23.639042
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...   592.913021   9.326123
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...   374.939530  27.305968
# ...                                                         ...        ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...   523.354248  23.387211
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...   377.825339  21.652471
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...  1951.164991  52.436964
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...   214.695243  38.827170
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...   682.159926  27.983013
#
#                                                         LF_NU         HF  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...  99.478197   2.993254
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...  97.509212  39.694850
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...  97.829386  14.536877
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...  98.817806   7.093235
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...  91.805057  33.468834
# ...                                                       ...        ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...  95.590958  24.139217
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...  92.337427  31.353638
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...  99.606646   7.705286
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...  91.263190  20.553211
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...  93.225787  49.568871
#
#                                                       HF_PCT     HF_NU  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...  0.122565  0.521803
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...  1.835677  2.490788
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...  0.524497  2.170614
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...  0.111572  1.182194
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...  2.437457  8.194943
# ...                                                      ...       ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...  1.078713  4.409042
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...  1.796819  7.662573
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...  0.207077  0.393354
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...  3.717004  8.736810
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...  2.033374  6.774213
#
#                                                              TP       LF_HF  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...  2442.168645  190.643094
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...  2162.409316   39.147940
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...  2771.583978   45.069921
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...  6357.550689   83.588517
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...  1373.104689   11.202647
# ...                                                         ...         ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...  2237.779643   21.680663
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...  1744.952487   12.050447
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...  3720.972447  253.224210
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...   552.951041   10.445825
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...  2437.764423   13.761861
#
#                                                     ...      KURT      SKEW  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...  ... -0.680262 -0.233075
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...  ... -0.034454 -0.051689
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...  ... -0.206953 -0.589940
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...  ... -0.820407  0.487198
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...  ...  1.738453 -0.005082
# ...                                                 ...       ...       ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...  ... -0.011224 -0.243444
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...  ...  6.540759  2.438418
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...  ...  0.973106 -0.681300
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...  ...  3.279160 -1.553159
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...  ...  0.908939  0.492250
#
#                                                     MEAN_REL_RR  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...     0.000016
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...     0.000040
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...     0.000010
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...    -0.000238
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...     0.000054
# ...                                                         ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...     0.000207
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...    -0.000113
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...     0.000306
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...    -0.000066
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...    -0.000264
#
#                                                     MEDIAN_REL_RR  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...       0.000288
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...      -0.002749
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...      -0.000172
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...      -0.000464
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...      -0.000006
# ...                                                           ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...      -0.000493
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...      -0.000139
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...       0.000430
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...      -0.000901
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...      -0.000588
#
#                                                     SDRR_REL_RR RMSSD_REL_RR  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...     0.012933     0.004578
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...     0.025148     0.013921
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...     0.015533     0.008149
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...     0.016882     0.007587
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...     0.013479     0.007811
# ...                                                         ...          ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...     0.014248     0.007564
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...     0.013108     0.007507
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...     0.022164     0.010680
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...     0.009878     0.006219
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...     0.019737     0.012549
#
#                                                     SDSD_REL_RR  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...     0.004578
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...     0.013921
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...     0.008149
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...     0.007587
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...     0.007811
# ...                                                         ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...     0.007564
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...     0.007507
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...     0.010680
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...     0.006219
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...     0.012549
#
#                                                     SDRR_RMSSD_REL_RR  \
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...           2.825038
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...           1.806517
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...           1.906180
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...           2.225116
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...           1.725606
# ...                                                               ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...           1.883681
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...           1.746077
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...           2.075297
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...           1.588346
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...           1.572749
#
#                                                     KURT_REL_RR  SKEW_REL_RR
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5...    -0.680262    -0.233075
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad...    -0.034454    -0.051689
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a...    -0.206953    -0.589940
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de...    -0.820407     0.487198
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f...     1.738453    -0.005082
# ...                                                         ...          ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232...    -0.011224    -0.243444
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36...     6.540759     2.438418
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b...     0.973106    -0.681300
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3...     3.279160    -1.553159
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0...     0.908939     0.492250
#
# [41033 rows x 34 columns]

# %%
print([each for each in df_test.columns if each not in df.columns])
# Out:
# []

# %%
df.shape,df_test.shape
# Out:
# ((369289, 36), (41033, 35))

# %%
df_test=pd.get_dummies(data=df_test,drop_first=True)

# %%
y_pred=model_reg_1.predict(df_test)

# %%
np.array(y_pred).flatten()
# Out:
# array([67.41239 , 73.63399 , 69.71267 , ..., 65.292786, 76.25115 ,
#        75.34108 ], dtype=float32)

# %%
y_pred=pd.Series(np.array(y_pred).flatten(),index=df_test.index)

# %%
y_pred
# Out:
# (62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5-bc40-4c8f-9166-daf0efcab4c2, 62b75db5-bc40-4c8f-9166-daf0efcab4c2)    67.412392
# (a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad-3eb6-4413-bc90-9053e7f7e684, a99549ad-3eb6-4413-bc90-9053e7f7e684)    73.633987
# (cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a-c767-4556-b32e-ad8c08ded214, cb573d3a-c767-4556-b32e-ad8c08ded214)    69.712669
# (47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de-2aef-4ac3-997d-252fa6fd07f1, 47a0c6de-2aef-4ac3-997d-252fa6fd07f1)    65.230637
# (de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f-c74e-4fe8-bf2a-7a127f68b312, de3fd54f-c74e-4fe8-bf2a-7a127f68b312)    76.320427
#                                                                                                                         ...
# (11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232-cf0a-4c40-abfb-ac2795effd9b, 11253232-cf0a-4c40-abfb-ac2795effd9b)    78.745163
# (38052c36-d08d-4305-905b-830f600ce2b9, 38052c36-d08d-4305-905b-830f600ce2b9, 38052c36-d08d-4305-905b-830f600ce2b9)    90.895859
# (8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b-512f-42ce-bcfd-47f5c1070bb0, 8ef3781b-512f-42ce-bcfd-47f5c1070bb0)    65.292786
# (2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3-af22-426d-91cf-e9e173ad3a54, 2bf689f3-af22-426d-91cf-e9e173ad3a54)    76.251152
# (0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0-e4d3-4ba3-b9ce-9c9291c8271e, 0b654db0-e4d3-4ba3-b9ce-9c9291c8271e)    75.341080
# Length: 41033, dtype: float32

# %%
type(df_test.index)
# Out:
# pandas.core.indexes.base.Index
