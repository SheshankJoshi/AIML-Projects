# %%
#Importing some modules here, but rest will be imported as per the requirement
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
import scipy.stats as stats
import warnings
warnings.simplefilter('ignore')

# %%
data2=pd.read_csv("Test_Dataset.csv",low_memory=False)

# %%
data2
# Out:
#              ID Client_Income  Car_Owned  Bike_Owned  Active_Loan  House_Own  \
# 0      12202227         11250        0.0         1.0          1.0        1.0
# 1      12279381         13500        1.0         1.0          1.0        1.0
# 2      12222714         38250        0.0         1.0          0.0        1.0
# 3      12265215         20250        0.0         0.0          1.0        0.0
# 4      12203970         13500        1.0         1.0          0.0        1.0
# ...         ...           ...        ...         ...          ...        ...
# 80895  12210181         11700        0.0         0.0          0.0        1.0
# 80896  12206257         29250        0.0         1.0          1.0        1.0
# 80897  12200446         54000        1.0         0.0          1.0        1.0
# 80898  12244943         13500        0.0         0.0          1.0        0.0
# 80899  12229890         10350        1.0         0.0          0.0        0.0
#
# ...

# %%
Categorical_columns=["Car_Owned",
                     "Bike_Owned",
                     "Active_Loan",
                     "House_Own",
                     "Accompany_Client",
                     "Client_Income_Type",
                     "Client_Education",
                     "Client_Marital_Status",
                     "Client_Gender",
                     "Loan_Contract_Type",
                     "Client_Housing_Type",
                     "Mobile_Tag",
                     "Homephone_Tag",
                     "Workphone_Working",
                     "Client_Occupation",
                     "Cleint_City_Rating",
                     "Application_Process_Day",
                     "Client_Permanent_Match_Tag",
                     "Client_Contact_Work_Tag",
                     "Type_Organization",
                     "Default"]

# %%
Numerical_columns=[]
for each in data2.columns:
    #print(each)
    if each in Categorical_columns:
        #print(each)
        pass
    else:
        Numerical_columns.append(each)
#######################################################3        
Numerical_columns.remove("ID")
Categorical_columns.remove("Default")

# %%
#These need some reason why they are not going along.
check=[]
for each in data2.columns:
    if each in Categorical_columns:
        try:
            data2[each]=data2[each].astype("category")
        except:
            check.append(each)
            continue
    elif each in Numerical_columns:
        try:
            data2[each]=data2[each].astype("float64")
        except:
            check.append(each)
            continue

# %%
check
# Out:
# ['Client_Income',
#  'Credit_Amount',
#  'Loan_Annuity',
#  'Population_Region_Relative',
#  'Age_Days',
#  'Employed_Days',
#  'Registration_Days',
#  'ID_Days',
#  'Score_Source_2',
#  'Score_Source_3']

# %%
symbols=[]
for col in check:
    for each in data2[col]:
        try :
            float(each)
        except:
            symbols.append(each)

# %%
for col in check:
    data2[col].replace(to_replace=symbols, value=np.nan, inplace=True)

# %%
for each in check:
    try:
        data2[each].astype("float64")
    except:
        print(each)
    finally:
        data2[each]=data2[each].astype("float64")

# %%
data2.dtypes
# Out:
# ID                               int64
# Client_Income                  float64
# Car_Owned                     category
# Bike_Owned                    category
# Active_Loan                   category
# House_Own                     category
# Child_Count                    float64
# Credit_Amount                  float64
# Loan_Annuity                   float64
# Accompany_Client              category
# Client_Income_Type            category
# Client_Education              category
# Client_Marital_Status         category
# Client_Gender                 category
# Loan_Contract_Type            category
# Client_Housing_Type           category
# Population_Region_Relative     float64
# Age_Days                       float64
# Employed_Days                  float64
# Registration_Days              float64
# ID_Days                        float64
# Own_House_Age                  float64
# Mobile_Tag                    category
# Homephone_Tag                 category
# ...

# %%
data2
# Out:
#              ID  Client_Income Car_Owned Bike_Owned Active_Loan House_Own  \
# 0      12202227        11250.0       0.0        1.0         1.0       1.0
# 1      12279381        13500.0       1.0        1.0         1.0       1.0
# 2      12222714        38250.0       0.0        1.0         0.0       1.0
# 3      12265215        20250.0       0.0        0.0         1.0       0.0
# 4      12203970        13500.0       1.0        1.0         0.0       1.0
# ...         ...            ...       ...        ...         ...       ...
# 80895  12210181        11700.0       0.0        0.0         0.0       1.0
# 80896  12206257        29250.0       0.0        1.0         1.0       1.0
# 80897  12200446        54000.0       1.0        0.0         1.0       1.0
# 80898  12244943        13500.0       0.0        0.0         1.0       0.0
# 80899  12229890        10350.0       1.0        0.0         0.0       0.0
#
#        Child_Count  Credit_Amount  Loan_Annuity Accompany_Client  ...  \
# ...

# %%
data2
# Out:
#              ID  Client_Income Car_Owned Bike_Owned Active_Loan House_Own  \
# 0      12202227        11250.0       0.0        1.0         1.0       1.0
# 1      12279381        13500.0       1.0        1.0         1.0       1.0
# 2      12222714        38250.0       0.0        1.0         0.0       1.0
# 3      12265215        20250.0       0.0        0.0         1.0       0.0
# 4      12203970        13500.0       1.0        1.0         0.0       1.0
# ...         ...            ...       ...        ...         ...       ...
# 80895  12210181        11700.0       0.0        0.0         0.0       1.0
# 80896  12206257        29250.0       0.0        1.0         1.0       1.0
# 80897  12200446        54000.0       1.0        0.0         1.0       1.0
# 80898  12244943        13500.0       0.0        0.0         1.0       0.0
# 80899  12229890        10350.0       1.0        0.0         0.0       0.0
#
#        Child_Count  Credit_Amount  Loan_Annuity Accompany_Client  ...  \
# ...

# %%
data2.to_csv("pre-processing done test_data.csv")

# %%
data3
# Out:
#        Unnamed: 0          ID  Client_Income  Car_Owned  Bike_Owned  \
# 0               0  12202227.0            NaN        0.0         1.0
# 1               1  12279381.0            NaN        1.0         1.0
# 2               2  12222714.0            NaN        0.0         1.0
# 3               3  12265215.0            NaN        0.0         0.0
# 4               4  12203970.0            NaN        1.0         1.0
# ...           ...         ...            ...        ...         ...
# 80895       80895  12210181.0            NaN        0.0         0.0
# 80896       80896  12206257.0            NaN        0.0         1.0
# 80897       80897  12200446.0            NaN        1.0         0.0
# 80898       80898  12244943.0            NaN        0.0         0.0
# 80899       80899  12229890.0            NaN        1.0         0.0
#
#        Active_Loan  House_Own  Child_Count  Credit_Amount  Loan_Annuity  ...  \
# ...

# %%
data3
# Out:
#                ID Client_Income Car_Owned Bike_Owned Active_Loan House_Own  \
# 0      12202227.0                     0.0        1.0         1.0       1.0
# 1      12279381.0                     1.0        1.0         1.0       1.0
# 2      12222714.0                     0.0        1.0         0.0       1.0
# 3      12265215.0                     0.0        0.0         1.0       0.0
# 4      12203970.0                     1.0        1.0         0.0       1.0
# ...           ...           ...       ...        ...         ...       ...
# 80895  12210181.0                     0.0        0.0         0.0       1.0
# 80896  12206257.0                     0.0        1.0         1.0       1.0
# 80897  12200446.0                     1.0        0.0         1.0       1.0
# 80898  12244943.0                     0.0        0.0         1.0       0.0
# 80899  12229890.0                     1.0        0.0         0.0       0.0
#
# ...

# %%
data2=data3.copy()

# %%
data2.describe()
# Out:
#                  ID   Child_Count  Own_House_Age  Client_Family_Members  \
# count  8.090000e+04  78572.000000   27319.000000           79256.000000
# mean   1.224045e+07      0.418393      12.013727               2.153288
# std    2.335396e+04      0.726007      11.937654               0.915802
# min    1.220000e+07      0.000000       0.000000               1.000000
# 25%    1.222023e+07      0.000000       5.000000               2.000000
# 50%    1.224045e+07      0.000000       9.000000               2.000000
# 75%    1.226068e+07      1.000000      15.000000               3.000000
# max    1.228090e+07     19.000000      65.000000              20.000000
#
#        Application_Process_Hour  Score_Source_1  Social_Circle_Default  \
# count              78494.000000    35407.000000           39810.000000
# mean                  12.070566        0.501752               0.117942
# std                    3.257224        0.211653               0.108621
# ...

# %%
to_modify=[]
########################################################
for each in data2.columns:
    if each in Categorical_columns:
        data2[each]=data2[each].astype("category")
        continue
    if each in Numerical_columns:
        try: 
            data2[each]=data2[each].astype("float64")
        except:
            print(each)
            for val in data2[each]:
                try:
                    float(val)
                except:
                    if type(val)==str:
                        to_modify.append([each,data2[each][data2[each]==val].index[0]])
#########################################################3
# Out:
# Client_Income
# Credit_Amount
# Loan_Annuity
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-2ebda4383aa2> in <module>
#       8         try:
# ----> 9             data2[each]=data2[each].astype("float64")
#      10         except:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#
# ...

# %%
data2.to_csv("pre-processing done test_data.csv")

# %%
data2.describe()
